# %%
# OOPs => Object Oriented Programming  (Secure)
# class , object , encapsulation , abstraction , polymorphism , inheritance

# %%
# class :- class is a virtual entity or  it is a blue print of an object

# %%
class class_name:
    x = 10

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
# Error:-  class is virtual

# %%
# Object:- Object is a real entity or representation of a class

# %%
class Car:
    color='Black'

# %%
obj = Car()

# %%
print(obj)

# %%
obj.color
# Out:
# 'Black'

# %%
obj2 = Car()

# %%
obj2.color
# Out:
# 'Black'

# %%
obj.color="Teal"

# %%
obj.color
# Out:
# 'Teal'

# %%
obj2.color
# Out:
# 'Black'
