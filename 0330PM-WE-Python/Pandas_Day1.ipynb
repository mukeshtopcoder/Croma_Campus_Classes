# %%
# pip install jupyter notebook
# pip install pandas
# pip install openpyxl

# %%
import pandas
import numpy as np

# %%
data = pandas.read_excel("c:/users/croma campus/Downloads/Financial_Sample.xlsx")

# %%
data
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
data.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
# 3   Midmarket  Germany  Carretera           NaN       888.0
# 4   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3        20.0      32370.0        0.0  32370.0  16185.0
# 1                    3        20.0      26420.0        0.0  26420.0  13210.0
# 2                    3        15.0      32670.0        0.0  32670.0  21780.0
# 3                    3        15.0      13320.0        0.0  13320.0   8880.0
# 4                    3        15.0      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
data.head(3)
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3        20.0      32370.0        0.0  32370.0  16185.0
# 1                    3        20.0      26420.0        0.0  26420.0  13210.0
# 2                    3        15.0      32670.0        0.0  32670.0  21780.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# 1  13210.0 2014-01-01             1    January  2014
# 2  10890.0 2014-06-01             6       June  2014

# %%
data.tail()
# Out:
#               Segment                   Country   Product Discount Band  \
# 695    Small Business                    France  Amarilla          High
# 696    Small Business                    Mexico  Amarilla          High
# 697        Government                    Mexico   Montana          High
# 698        Government                    Canada     Paseo          High
# 699  Channel Partners  United States of America       VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 695      2475.0                  260       300.0     742500.0  111375.00
# 696       546.0                  260       300.0     163800.0   24570.00
# 697      1368.0                    5         7.0       9576.0    1436.40
# 698       723.0                   10         7.0       5061.0     759.15
# 699      1806.0                  250        12.0      21672.0    3250.80
#
#          Sales      COGS    Profit       Date  Month Number Month Name  Year
# ...

# %%
data.tail(3)
# Out:
#               Segment                   Country  Product Discount Band  \
# 697        Government                    Mexico  Montana          High
# 698        Government                    Canada    Paseo          High
# 699  Channel Partners  United States of America      VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 697      1368.0                    5         7.0       9576.0    1436.40
# 698       723.0                   10         7.0       5061.0     759.15
# 699      1806.0                  250        12.0      21672.0    3250.80
#
#         Sales    COGS    Profit       Date  Month Number Month Name  Year
# 697   8139.60  6840.0   1299.60 2014-02-01             2   February  2014
# 698   4301.85  3615.0    686.85 2014-04-01             4      April  2014
# 699  18421.20  5418.0  13003.20 2014-05-01             5        May  2014

# %%
data.head(25)
# Out:
#              Segment                   Country    Product Discount Band  \
# 0         Government                    Canada  Carretera           NaN
# 1         Government                   Germany  Carretera           NaN
# 2          Midmarket                    France  Carretera           NaN
# 3          Midmarket                   Germany  Carretera           NaN
# 4          Midmarket                    Mexico  Carretera           NaN
# 5         Government                   Germany  Carretera           NaN
# 6          Midmarket                   Germany    Montana           NaN
# 7   Channel Partners                    Canada    Montana           NaN
# 8         Government                    France    Montana           NaN
# 9   Channel Partners                   Germany    Montana           NaN
# 10         Midmarket                    Mexico    Montana           NaN
# 11        Enterprise                    Canada    Montana           NaN
# ...

# %%
data = {
    'EMPID':[101,102,103,104,105,106,107,108,109,110],
    'EMP_Name':['Raj','Anu','Manu','Rahul','Ram','Shyam','Mohan','Rohan','Shiva','Vikas'],
    'EMP_Salary':[24345,76654,87675,23344,67563,78999,34566,87887,78009,43665]
}

# %%
df =
# Out:
# {'EMPID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
#  'EMP_Name': ['Raj',
#   'Anu',
#   'Manu',
#   'Rahul',
#   'Ram',
#   'Shyam',
#   'Mohan',
#   'Rohan',
#   'Shiva',
#   'Vikas'],
#  'EMP_Salary': [24345,
#   76654,
#   87675,
#   23344,
#   67563,
#   78999,
#   34566,
#   87887,
#   78009,
#   43665]}

# %%
df = pandas.DataFrame(data)

# %%
df
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj       24345
# 1    102      Anu       76654
# 2    103     Manu       87675
# 3    104    Rahul       23344
# 4    105      Ram       67563
# 5    106    Shyam       78999
# 6    107    Mohan       34566
# 7    108    Rohan       87887
# 8    109    Shiva       78009
# 9    110    Vikas       43665

# %%
# Aggreagte Functions

# %%
df.head()
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj       24345
# 1    102      Anu       76654
# 2    103     Manu       87675
# 3    104    Rahul       23344
# 4    105      Ram       67563

# %%
df['EMP_Salary']
# Out:
# 0    24345
# 1    76654
# 2    87675
# 3    23344
# 4    67563
# 5    78999
# 6    34566
# 7    87887
# 8    78009
# 9    43665
# Name: EMP_Salary, dtype: int64

# %%
df.EMP_Salary
# Out:
# 0    24345
# 1    76654
# 2    87675
# 3    23344
# 4    67563
# 5    78999
# 6    34566
# 7    87887
# 8    78009
# 9    43665
# Name: EMP_Salary, dtype: int64

# %%
df.EMP_Salary.sum()
# Out:
# np.int64(602707)

# %%
df.EMP_Salary.max()
# Out:
# np.int64(87887)

# %%
df.EMP_Salary.min()
# Out:
# np.int64(23344)

# %%
df.EMP_Salary.count()
# Out:
# np.int64(10)

# %%
print("Average Salary" ,df.EMP_Salary.sum()/df.EMP_Salary.count() )
# Out:
# Average Salary 60270.7

# %%
data = {
    'EMPID':[101,102,103,104,105,106,107,108,109,110],
    'EMP_Name':['Raj','Anu',np.nan,'Rahul','Ram','Shyam',np.nan,'Rohan','Shiva','Vikas'],
    'EMP_Salary':[24345,np.nan,87675,23344,67563,np.nan,34566,np.nan,78009,43665]
}

# %%
df = pandas.DataFrame(data)

# %%
df
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj     24345.0
# 1    102      Anu         NaN
# 2    103      NaN     87675.0
# 3    104    Rahul     23344.0
# 4    105      Ram     67563.0
# 5    106    Shyam         NaN
# 6    107      NaN     34566.0
# 7    108    Rohan         NaN
# 8    109    Shiva     78009.0
# 9    110    Vikas     43665.0

# %%
df.isnull()
# Out:
#    EMPID  EMP_Name  EMP_Salary
# 0  False     False       False
# 1  False     False        True
# 2  False      True       False
# 3  False     False       False
# 4  False     False       False
# 5  False     False        True
# 6  False      True       False
# 7  False     False        True
# 8  False     False       False
# 9  False     False       False

# %%
df.isnull().sum()
# Out:
# EMPID         0
# EMP_Name      2
# EMP_Salary    3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(5)

# %%
df.EMP_Salary.isnull().sum()
# Out:
# np.int64(3)

# %%
df
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj     24345.0
# 1    102      Anu         NaN
# 2    103      NaN     87675.0
# 3    104    Rahul     23344.0
# 4    105      Ram     67563.0
# 5    106    Shyam         NaN
# 6    107      NaN     34566.0
# 7    108    Rohan         NaN
# 8    109    Shiva     78009.0
# 9    110    Vikas     43665.0

# %%
df.EMP_Salary.sum()
# Out:
# np.float64(359167.0)

# %%
df = df.dropna()

# %%
df
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj     24345.0
# 3    104    Rahul     23344.0
# 4    105      Ram     67563.0
# 8    109    Shiva     78009.0
# 9    110    Vikas     43665.0

# %%
df.to_csv('abcd.csv')

# %%
df
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj     24345.0
# 1    102      Anu         NaN
# 2    103      NaN     87675.0
# 3    104    Rahul     23344.0
# 4    105      Ram     67563.0
# 5    106    Shyam         NaN
# 6    107      NaN     34566.0
# 7    108    Rohan         NaN
# 8    109    Shiva     78009.0
# 9    110    Vikas     43665.0

# %%
df.dropna()
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj     24345.0
# 3    104    Rahul     23344.0
# 4    105      Ram     67563.0
# 8    109    Shiva     78009.0
# 9    110    Vikas     43665.0

# %%
# remove /Dropna  =>   0.0% - 1.0%

# %%
# replace / repair

# %%
# fillna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EMPID       10 non-null     int64
#  1   EMP_Name    8 non-null      object
#  2   EMP_Salary  7 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.0+ bytes

# %%
df = df.fillna(value='Missing_Value')

# %%
df
# Out:
#    EMPID       EMP_Name     EMP_Salary
# 0    101            Raj        24345.0
# 1    102            Anu  Missing_Value
# 2    103  Missing_Value        87675.0
# 3    104          Rahul        23344.0
# 4    105            Ram        67563.0
# 5    106          Shyam  Missing_Value
# 6    107  Missing_Value        34566.0
# 7    108          Rohan  Missing_Value
# 8    109          Shiva        78009.0
# 9    110          Vikas        43665.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EMPID       10 non-null     int64
#  1   EMP_Name    10 non-null     object
#  2   EMP_Salary  10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj     24345.0
# 1    102      Anu         NaN
# 2    103      NaN     87675.0
# 3    104    Rahul     23344.0
# 4    105      Ram     67563.0
# 5    106    Shyam         NaN
# 6    107      NaN     34566.0
# 7    108    Rohan         NaN
# 8    109    Shiva     78009.0
# 9    110    Vikas     43665.0

# %%
df.EMP_Name.fillna(value='Unknown_Name',inplace=True)
# Out:
# C:\Users\Croma Campus\AppData\Local\Temp\ipykernel_17832\2766513730.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.EMP_Name.fillna(value='Unknown_Name',inplace=True)

# %%
df
# Out:
#    EMPID      EMP_Name  EMP_Salary
# 0    101           Raj     24345.0
# 1    102           Anu         NaN
# 2    103  Unknown_Name     87675.0
# 3    104         Rahul     23344.0
# 4    105           Ram     67563.0
# 5    106         Shyam         NaN
# 6    107  Unknown_Name     34566.0
# 7    108         Rohan         NaN
# 8    109         Shiva     78009.0
# 9    110         Vikas     43665.0

# %%
df.EMP_Salary.sum()
# Out:
# np.float64(359167.0)

# %%
df.EMP_Salary.sum()/df.EMP_Salary.count()
# Out:
# np.float64(51309.57142857143)

# %%
df.EMP_Salary.isnull().sum()
# Out:
# np.int64(3)

# %%
df.EMP_Salary.fillna(value=0,inplace=True)
# Out:
# C:\Users\Croma Campus\AppData\Local\Temp\ipykernel_17832\3500300130.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.EMP_Salary.fillna(value=0,inplace=True)

# %%
df
# Out:
#    EMPID      EMP_Name  EMP_Salary
# 0    101           Raj     24345.0
# 1    102           Anu         0.0
# 2    103  Unknown_Name     87675.0
# 3    104         Rahul     23344.0
# 4    105           Ram     67563.0
# 5    106         Shyam         0.0
# 6    107  Unknown_Name     34566.0
# 7    108         Rohan         0.0
# 8    109         Shiva     78009.0
# 9    110         Vikas     43665.0

# %%
df.EMP_Salary.sum()
# Out:
# np.float64(359167.0)

# %%
df.EMP_Salary.sum()/df.EMP_Salary.count()
# Out:
# np.float64(35916.7)

# %%
df
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj     24345.0
# 1    102      Anu         NaN
# 2    103      NaN     87675.0
# 3    104    Rahul     23344.0
# 4    105      Ram     67563.0
# 5    106    Shyam         NaN
# 6    107      NaN     34566.0
# 7    108    Rohan         NaN
# 8    109    Shiva     78009.0
# 9    110    Vikas     43665.0

# %%
df.EMP_Name.mode()
# Out:
# 0      Anu
# 1    Rahul
# 2      Raj
# 3      Ram
# 4    Rohan
# 5    Shiva
# 6    Shyam
# 7    Vikas
# Name: EMP_Name, dtype: object

# %%
df.EMP_Name.fillna(value=df.EMP_Name.mode()[0] , inplace=True)
# Out:
# C:\Users\Croma Campus\AppData\Local\Temp\ipykernel_17832\1387152996.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.EMP_Name.fillna(value=df.EMP_Name.mode()[0] , inplace=True)

# %%
df.EMP_Salary.sum()/df.EMP_Salary.count()
# Out:
# np.float64(51309.57142857143)

# %%
df.EMP_Salary.fillna(value=df.EMP_Salary.sum()/df.EMP_Salary.count() , inplace=True)

# %%
df
# Out:
#    EMPID EMP_Name    EMP_Salary
# 0    101      Raj  24345.000000
# 1    102      Anu  51309.571429
# 2    103      Anu  87675.000000
# 3    104    Rahul  23344.000000
# 4    105      Ram  67563.000000
# 5    106    Shyam  51309.571429
# 6    107      Anu  34566.000000
# 7    108    Rohan  51309.571429
# 8    109    Shiva  78009.000000
# 9    110    Vikas  43665.000000

# %%
df.EMP_Salary.sum()/df.EMP_Salary.count()
# Out:
# np.float64(51309.57142857143)

# %%
data = {
    'EMPID':[101,102,103,104,104,106,107,104,107,110],
    'EMP_Name':['Raj','Anu','Manu','Rahul','Ram','Shyam','Mohan','Rohan','Shiva','Vikas'],
    'EMP_Salary':[24345,76654,87675,23344,67563,78999,34566,87887,78009,43665]
}

# %%
df = pandas.DataFrame(data)

# %%
df
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0    101      Raj       24345
# 1    102      Anu       76654
# 2    103     Manu       87675
# 3    104    Rahul       23344
# 4    104      Ram       67563
# 5    106    Shyam       78999
# 6    107    Mohan       34566
# 7    104    Rohan       87887
# 8    107    Shiva       78009
# 9    110    Vikas       43665

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.EMPID.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7     True
# 8     True
# 9    False
# Name: EMPID, dtype: bool

# %%
df.EMPID = df.EMPID.drop_duplicates()

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#    EMPID EMP_Name  EMP_Salary
# 0  101.0      Raj       24345
# 1  102.0      Anu       76654
# 2  103.0     Manu       87675
# 3  104.0    Rahul       23344
# 5  106.0    Shyam       78999
# 6  107.0    Mohan       34566
# 9  110.0    Vikas       43665
