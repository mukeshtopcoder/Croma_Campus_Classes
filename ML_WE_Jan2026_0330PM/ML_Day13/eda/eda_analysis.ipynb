# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset("tips")

# %%
df.shape
# Out:
# (244, 7)

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.sex.unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']

# %%
df.smoker.unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
df.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
X = df[["total_bill", "size", "sex", "smoker", "day", "time" ]]

# %%
X.sex = X.sex.map(lambda x: 1 if x == 'Male' else 0 )
X.smoker = X.smoker.map(lambda x: 1 if x == 'Yes' else 0 )
X.day = X.day.map(lambda x: list(X.day.unique()).index(x))
X.time = X.time.map(lambda x: 0 if x == 'Lunch' else 1)
# Out:
# C:\Users\THIS\AppData\Local\Temp\ipykernel_9172\1247566965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.sex = X.sex.map(lambda x: 1 if x == 'Male' else 0 )
# C:\Users\THIS\AppData\Local\Temp\ipykernel_9172\1247566965.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.smoker = X.smoker.map(lambda x: 1 if x == 'Yes' else 0 )
# C:\Users\THIS\AppData\Local\Temp\ipykernel_9172\1247566965.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.day = X.day.map(lambda x: list(X.day.unique()).index(x))
# C:\Users\THIS\AppData\Local\Temp\ipykernel_9172\1247566965.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.time = X.time.map(lambda x: 0 if x == 'Lunch' else 1)

# %%
X
# Out:
#      total_bill  size sex smoker day time
# 0         16.99     2   0      0   0    1
# 1         10.34     3   1      0   0    1
# 2         21.01     3   1      0   0    1
# 3         23.68     2   1      0   0    1
# 4         24.59     4   0      0   0    1
# ..          ...   ...  ..    ...  ..  ...
# 239       29.03     3   1      0   1    1
# 240       27.18     2   0      1   1    1
# 241       22.67     2   1      1   1    1
# 242       17.82     2   1      0   1    1
# 243       18.78     2   0      0   2    1
#
# [244 rows x 6 columns]
