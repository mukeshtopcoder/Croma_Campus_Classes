# %% [markdown]
# # Time Series Analysis
# ##### A Time series data is collected over the time

# %% [markdown]
# ###### Data Order Matters -> You can not shuffle the data

# %% [markdown]
# ##### Components of Time Series (VERY IMPORTANT)
# - Trend   (Long-Term Increase/Decrease)
# - Seasonality  (Repeating Pattern)
# - Cyclic  (Irregular long cycles)
# - Noise   (Random Variation)

# %% [markdown]
# #### Stationarity
# - Mean is constant
# - Varianve is constant
# - No Trend/Seasonality

# %% [markdown]
# ##### Using ADF you can check Stationarity
# - p-value < 0.05 Stationary
# - p-value > 0.05 Not- Stationary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create Data Range
dates = pd.date_range( start='2025-1-1' , periods=365 , freq="D" )
dates[:5]
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Create Components
trend = np.linspace(10,100,365)
season = 10*np.sin( np.linspace(0,50,365) )
noise = np.random.normal( 0,5,365 )  
value = trend+season+noise
value[:10]
# Out:
# array([ 8.86726575, 13.60905114, 13.68224032, 14.16997108, 18.35879549,
#        15.93795061, 27.5949237 , 21.56594237, 30.33449455, 23.58662171])

# %%
df = pd.DataFrame({
    'Date':dates , 
    'Price':value
})

# %%
df.head(10)
# Out:
#         Date      Price
# 0 2025-01-01   8.867266
# 1 2025-01-02  13.609051
# 2 2025-01-03  13.682240
# 3 2025-01-04  14.169971
# 4 2025-01-05  18.358795
# 5 2025-01-06  15.937951
# 6 2025-01-07  27.594924
# 7 2025-01-08  21.565942
# 8 2025-01-09  30.334495
# 9 2025-01-10  23.586622

# %%
df = df.set_index('Date')

# %%
df.head(10)
# Out:
#                 Price
# Date
# 2025-01-01   8.867266
# 2025-01-02  13.609051
# 2025-01-03  13.682240
# 2025-01-04  14.169971
# 2025-01-05  18.358795
# 2025-01-06  15.937951
# 2025-01-07  27.594924
# 2025-01-08  21.565942
# 2025-01-09  30.334495
# 2025-01-10  23.586622

# %%
plt.figure(figsize=(8,3))
plt.plot(df.index ,  df['Price'] )
plt.title("Synthetic Time Series Data")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()
