# %%
# Seaborn Library

# %%
# !pip install seaborn
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Users\THIS\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\THIS\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\THIS\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# distance plot  => displot()

# %%
y = [0,1,2,3,4,5]

# %%
sns.displot(y)

# %%
plt.figure(figsize=(3,2))
sns.displot(y)
plt.show()

# %%
plt.figure(figsize=(3,2))
sns.displot(y , kind='kde' )
plt.show()

# %%
y = [21,43,56,78,90,87,76,45,23,12]

# %%
plt.figure(figsize=(3,2))
sns.displot(y , kind='kde' )
plt.show()

# %%
y = [21,43,56,78,90,87,500,45,1000,23,12]

# %%
plt.figure(figsize=(3,2))
sns.displot(y , kind='kde' )
plt.show()

# %%
# it was a normal distribution and we found a long tail on the right side of the graph
# That mean, dataset has variance (and may be outliers)

# %%
import numpy as np
from numpy import random

# %%
sns.displot( random.binomial(n=10 , p=0.5 , size=1000) )
plt.show()

# %%
data = {
    'normal':random.normal(loc=50,scale=5,size=1000),
    'binomial':random.binomial(n=100,p=0.5,size=1000)
}

# %%
sns.displot(data,kind='kde')
plt.show()

# %%
y = [0,1,2,3,4,5]

# %%
sns.boxplot(y)
plt.show()

# %%
y = [23,45,98,76,32,1,56,89,9,45,23,56]

# %%
plt.figure(figsize=(6,2))
sns.boxplot(y)
plt.show()

# %%
y = [23,45,98,76,32,1,500,56,89,9,45,1000,23,56]

# %%
plt.figure(figsize=(6,2))
sns.boxplot(y)
plt.show()

# %%
data = sns.load_dataset('iris')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.figure(figsize=(6,3))
sns.lineplot( x='sepal_length' , y = 'sepal_width' , data=data)
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.lineplot( x='sepal_length' , y = 'sepal_width' , data=data)
plt.title('Distribution of Sepal Length and Width')
plt.show()

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.figure(figsize=(6,3))
plt.subplot(2,1,1)
sns.lineplot( x='sepal_length' , y = 'sepal_width' , data=data)
plt.subplot(2,1,2)
sns.lineplot( x='petal_length' , y = 'petal_width' , data=data)
plt.suptitle('Distribution of Sepal and Petal')
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.barplot(x='species' , y='sepal_length' , data=data)
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.countplot(x='species' , data=data)
plt.show()

# %%
data['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (150, 5)

# %%
plt.figure(figsize=(6,2))
sns.barplot(x='species' , y='sepal_width' , data=data)
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.boxplot(x='species' , y='sepal_length' , data=data)
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.violinplot(x='species' , y='sepal_length' , data=data)
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.stripplot(x='species' , y='sepal_length' , data=data)
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.swarmplot(x='species' , y='sepal_length' , data=data)
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.catplot(x='species' , y='sepal_length' , data=data)
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.histplot(x='species' , y='sepal_length' , data=data)
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.displot(data['sepal_width'])
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.distplot(data['sepal_width'])
plt.show()
# Out:
# C:\Users\THIS\AppData\Local\Temp\ipykernel_28076\3646409367.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['sepal_width'])

# %%
plt.figure(figsize=(6,2))
sns.pairplot(data=data , hue='species')
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.rugplot(data=data)
plt.show()
