# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Croma Campus\Downloads\Churn_Modelling.csv")

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.head(4)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0

# %%
df.Geography.unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df.Exited
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
df.groupby('Gender').agg({'Exited':'count'})
# Out:
#         Exited
# Gender
# Female    4543
# Male      5457

# %%
df.groupby('Gender').agg({'Exited':'sum'})
# Out:
#         Exited
# Gender
# Female    1139
# Male       898

# %%
df.groupby('Geography').agg({'Exited':'count'})
# Out:
#            Exited
# Geography
# France       5014
# Germany      2509
# Spain        2477

# %%
df.groupby('Geography').agg({'Exited':'sum'})
# Out:
#            Exited
# Geography
# France        810
# Germany       814
# Spain         413
