# %%
# Classification Model

# %%
# Logistic Regression

# %%
# z = w1x1 + w2x2 + w3x3 + ... + b
# w => weight (slope)
# x => feature(input)
# b => constant (Intercept (starting point) - bias)

# %%
# Sigmoid Function (try to take output between 0 to 1)
# v = 1/(1-e^z)

# %%
# Data Generation
# Train-Test Split
# Model Training
# Prediction
# Probability 
# coefficients and bias
# Decision Boundary
# Metrics
