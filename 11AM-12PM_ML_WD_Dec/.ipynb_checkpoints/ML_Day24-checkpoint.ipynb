# %% [markdown]
# ### Time Series Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Date Range
date_range = pd.date_range(start="2021-01-01" , periods=60 , freq="ME")

# %%
# Sales
sales = 200 + np.arange(60)*5 + np.random.normal(0,20,60)

# %%
data = {
    "Date":date_range,
    "Sales":sales
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#         Date       Sales
# 0 2021-01-31  207.260175
# 1 2021-02-28  236.460755
# 2 2021-03-31  195.135921
# 3 2021-04-30  240.933729
# 4 2021-05-31  243.726593

# %%
df = df.set_index('Date')

# %%
df.head()
# Out:
#                  Sales
# Date
# 2021-01-31  207.260175
# 2021-02-28  236.460755
# 2021-03-31  195.135921
# 2021-04-30  240.933729
# 2021-05-31  243.726593

# %%
plt.figure(figsize=(6,3))
plt.plot(df , label='Sales')
plt.title("Monthly Sales Analysis")
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid()
plt.show()

# %%
# !pip install statsmodels

# %%
# Time Series Component
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decompose = seasonal_decompose( df['Sales'] , model="additive" )

# %%
decompose.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(df['Sales'])

# %%
# p-value
result[1]
# Out:
# np.float64(0.9708981033409738)
