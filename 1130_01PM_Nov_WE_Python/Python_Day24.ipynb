# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
import pandas as pd
import numpy as np

# %%
# Pandas is a library to work Series and DataFrame
# Series :- One Dimensional Data 1D List,Array,Tuple
# DataFrame :- 2D Dataset (in the tabular format (rows/cols))

# %%
# Pandas is use to manipulate, Transform and clean the data

# %%
data = {
    'EmpID':[101,102,103,104,105,106,107,108,109,110],
    'EmpName':['Raj','Anu','Manu','Siya','Aman','Ram','Shyam','Mohan','Ravi','Yogesh'],
    'EmpSalary':[23440,67440,45340,78756,34550,56650,32450,78970,44500,38300],
    'EmpAdd':['Noida','Delhi','GZB','Noida','Noida','Delhi','GZB','Noida','Noida','Delhi']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    EmpID EmpName  EmpSalary EmpAdd
# 0    101     Raj      23440  Noida
# 1    102     Anu      67440  Delhi
# 2    103    Manu      45340    GZB
# 3    104    Siya      78756  Noida
# 4    105    Aman      34550  Noida
# 5    106     Ram      56650  Delhi
# 6    107   Shyam      32450    GZB
# 7    108   Mohan      78970  Noida
# 8    109    Ravi      44500  Noida
# 9    110  Yogesh      38300  Delhi

# %%
df.head()
# Out:
#    EmpID EmpName  EmpSalary EmpAdd
# 0    101     Raj      23440  Noida
# 1    102     Anu      67440  Delhi
# 2    103    Manu      45340    GZB
# 3    104    Siya      78756  Noida
# 4    105    Aman      34550  Noida

# %%
df.head(3)
# Out:
#    EmpID EmpName  EmpSalary EmpAdd
# 0    101     Raj      23440  Noida
# 1    102     Anu      67440  Delhi
# 2    103    Manu      45340    GZB

# %%
df.tail()
# Out:
#    EmpID EmpName  EmpSalary EmpAdd
# 5    106     Ram      56650  Delhi
# 6    107   Shyam      32450    GZB
# 7    108   Mohan      78970  Noida
# 8    109    Ravi      44500  Noida
# 9    110  Yogesh      38300  Delhi

# %%
df.tail(2)
# Out:
#    EmpID EmpName  EmpSalary EmpAdd
# 8    109    Ravi      44500  Noida
# 9    110  Yogesh      38300  Delhi

# %%
df.shape
# Out:
# (10, 4)

# %%
print("Rows :",df.shape[0])
print("Cols :",df.shape[1])
# Out:
# Rows : 10
# Cols : 4

# %%
df.columns
# Out:
# Index(['EmpID', 'EmpName', 'EmpSalary', 'EmpAdd'], dtype='object')

# %%
df.EmpName
# Out:
# 0       Raj
# 1       Anu
# 2      Manu
# 3      Siya
# 4      Aman
# 5       Ram
# 6     Shyam
# 7     Mohan
# 8      Ravi
# 9    Yogesh
# Name: EmpName, dtype: object

# %%
df['EmpName']
# Out:
# 0       Raj
# 1       Anu
# 2      Manu
# 3      Siya
# 4      Aman
# 5       Ram
# 6     Shyam
# 7     Mohan
# 8      Ravi
# 9    Yogesh
# Name: EmpName, dtype: object

# %%
df[['EmpName','EmpSalary']]
# Out:
#   EmpName  EmpSalary
# 0     Raj      23440
# 1     Anu      67440
# 2    Manu      45340
# 3    Siya      78756
# 4    Aman      34550
# 5     Ram      56650
# 6   Shyam      32450
# 7   Mohan      78970
# 8    Ravi      44500
# 9  Yogesh      38300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   EmpID      10 non-null     int64
#  1   EmpName    10 non-null     object
#  2   EmpSalary  10 non-null     int64
#  3   EmpAdd     10 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#            EmpID     EmpSalary
# count   10.00000     10.000000
# mean   105.50000  50039.600000
# std      3.02765  19594.565727
# min    101.00000  23440.000000
# 25%    103.25000  35487.500000
# 50%    105.50000  44920.000000
# 75%    107.75000  64742.500000
# max    110.00000  78970.000000

# %%
data = {
    'EmpID':[101,102,103,104,105,106,107,108,109,110],
    'EmpName':['Raj','Anu','Manu','Siya',np.nan,'Ram','Shyam','Mohan','Ravi','Yogesh'],
    'EmpSalary':[23440,67440,np.nan,78756,34550,56650,32450,78970,np.nan,38300],
    'EmpAdd':['Noida','Delhi','GZB',np.nan,'Noida','Delhi',np.nan,np.nan,'Noida','Delhi']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    EmpID EmpName  EmpSalary EmpAdd
# 0    101     Raj    23440.0  Noida
# 1    102     Anu    67440.0  Delhi
# 2    103    Manu        NaN    GZB
# 3    104    Siya    78756.0    NaN
# 4    105     NaN    34550.0  Noida
# 5    106     Ram    56650.0  Delhi
# 6    107   Shyam    32450.0    NaN
# 7    108   Mohan    78970.0    NaN
# 8    109    Ravi        NaN  Noida
# 9    110  Yogesh    38300.0  Delhi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   EmpID      10 non-null     int64
#  1   EmpName    9 non-null      object
#  2   EmpSalary  8 non-null      float64
#  3   EmpAdd     7 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes

# %%
df.isnull()
# Out:
#    EmpID  EmpName  EmpSalary  EmpAdd
# 0  False    False      False   False
# 1  False    False      False   False
# 2  False    False       True   False
# 3  False    False      False    True
# 4  False     True      False   False
# 5  False    False      False   False
# 6  False    False      False    True
# 7  False    False      False    True
# 8  False    False       True   False
# 9  False    False      False   False

# %%
df.isnull().sum()
# Out:
# EmpID        0
# EmpName      1
# EmpSalary    2
# EmpAdd       3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(6)

# %%
newdf = df.dropna()   # remove missing values

# %%
newdf
# Out:
#    EmpID EmpName  EmpSalary EmpAdd
# 0    101     Raj    23440.0  Noida
# 1    102     Anu    67440.0  Delhi
# 5    106     Ram    56650.0  Delhi
# 9    110  Yogesh    38300.0  Delhi

# %%
newdf.EmpSalary
# Out:
# 0    23440.0
# 1    67440.0
# 5    56650.0
# 9    38300.0
# Name: EmpSalary, dtype: float64

# %%
newdf.EmpSalary.sum()
# Out:
# np.float64(185830.0)

# %%
df.EmpSalary
# Out:
# 0    23440.0
# 1    67440.0
# 2        NaN
# 3    78756.0
# 4    34550.0
# 5    56650.0
# 6    32450.0
# 7    78970.0
# 8        NaN
# 9    38300.0
# Name: EmpSalary, dtype: float64

# %%
df.EmpSalary.sum()
# Out:
# np.float64(410556.0)

# %%
newdf = df.fillna(value='Missing_Data')

# %%
newdf.shape
# Out:
# (10, 4)

# %%
newdf
# Out:
#    EmpID       EmpName     EmpSalary        EmpAdd
# 0    101           Raj       23440.0         Noida
# 1    102           Anu       67440.0         Delhi
# 2    103          Manu  Missing_Data           GZB
# 3    104          Siya       78756.0  Missing_Data
# 4    105  Missing_Data       34550.0         Noida
# 5    106           Ram       56650.0         Delhi
# 6    107         Shyam       32450.0  Missing_Data
# 7    108         Mohan       78970.0  Missing_Data
# 8    109          Ravi  Missing_Data         Noida
# 9    110        Yogesh       38300.0         Delhi

# %%
newdf.isnull().sum()
# Out:
# EmpID        0
# EmpName      0
# EmpSalary    0
# EmpAdd       0
# dtype: int64

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   EmpID      10 non-null     int64
#  1   EmpName    10 non-null     object
#  2   EmpSalary  10 non-null     object
#  3   EmpAdd     10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 452.0+ bytes

# %%
newdf.EmpSalary
# Out:
# 0         23440.0
# 1         67440.0
# 2    Missing_Data
# 3         78756.0
# 4         34550.0
# 5         56650.0
# 6         32450.0
# 7         78970.0
# 8    Missing_Data
# 9         38300.0
# Name: EmpSalary, dtype: object

# %%
# newdf.EmpSalary.sum()
# now EmpSalary is an object column

# %%
df
# Out:
#    EmpID EmpName  EmpSalary EmpAdd
# 0    101     Raj    23440.0  Noida
# 1    102     Anu    67440.0  Delhi
# 2    103    Manu        NaN    GZB
# 3    104    Siya    78756.0    NaN
# 4    105     NaN    34550.0  Noida
# 5    106     Ram    56650.0  Delhi
# 6    107   Shyam    32450.0    NaN
# 7    108   Mohan    78970.0    NaN
# 8    109    Ravi        NaN  Noida
# 9    110  Yogesh    38300.0  Delhi

# %%
newdf = df.copy()

# %%
newdf.EmpSalary = newdf.EmpSalary.fillna(value = 0)

# %%
newdf
# Out:
#    EmpID EmpName  EmpSalary EmpAdd
# 0    101     Raj    23440.0  Noida
# 1    102     Anu    67440.0  Delhi
# 2    103    Manu        0.0    GZB
# 3    104    Siya    78756.0    NaN
# 4    105     NaN    34550.0  Noida
# 5    106     Ram    56650.0  Delhi
# 6    107   Shyam    32450.0    NaN
# 7    108   Mohan    78970.0    NaN
# 8    109    Ravi        0.0  Noida
# 9    110  Yogesh    38300.0  Delhi

# %%
newdf.isnull().sum()
# Out:
# EmpID        0
# EmpName      1
# EmpSalary    0
# EmpAdd       3
# dtype: int64

# %%
newdf = newdf.fillna(value='Unknown')

# %%
newdf
# Out:
#    EmpID  EmpName  EmpSalary   EmpAdd
# 0    101      Raj    23440.0    Noida
# 1    102      Anu    67440.0    Delhi
# 2    103     Manu        0.0      GZB
# 3    104     Siya    78756.0  Unknown
# 4    105  Unknown    34550.0    Noida
# 5    106      Ram    56650.0    Delhi
# 6    107    Shyam    32450.0  Unknown
# 7    108    Mohan    78970.0  Unknown
# 8    109     Ravi        0.0    Noida
# 9    110   Yogesh    38300.0    Delhi

# %%
newdf.isnull().sum()
# Out:
# EmpID        0
# EmpName      0
# EmpSalary    0
# EmpAdd       0
# dtype: int64

# %%
newdf.EmpSalary
# Out:
# 0    23440.0
# 1    67440.0
# 2        0.0
# 3    78756.0
# 4    34550.0
# 5    56650.0
# 6    32450.0
# 7    78970.0
# 8        0.0
# 9    38300.0
# Name: EmpSalary, dtype: float64

# %%
newdf.EmpSalary.sum()
# Out:
# np.float64(410556.0)
