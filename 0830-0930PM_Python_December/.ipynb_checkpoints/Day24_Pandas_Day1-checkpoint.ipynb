# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# If you want to load an excel
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data = {
    'empid':[101,102,103,104,105,106,107,108],
    'empname':['Raju','Raman','Siya','Simran','Yogesh','Ravi','Mahesh','Vikas'],
    'empsal':[24565,78656,36654,87686,13324,67545,15263,21355]
}

# %%
print(data)
# Out:
# {'empid': [101, 102, 103, 104, 105, 106, 107, 108], 'empname': ['Raju', 'Raman', 'Siya', 'Simran', 'Yogesh', 'Ravi', 'Mahesh', 'Vikas'], 'empsal': [24565, 78656, 36654, 87686, 13324, 67545, 15263, 21355]}

# %%
data
# Out:
# {'empid': [101, 102, 103, 104, 105, 106, 107, 108],
#  'empname': ['Raju',
#   'Raman',
#   'Siya',
#   'Simran',
#   'Yogesh',
#   'Ravi',
#   'Mahesh',
#   'Vikas'],
#  'empsal': [24565, 78656, 36654, 87686, 13324, 67545, 15263, 21355]}

# %%
# With pandas you can work on Series(1D) , DataFrames(2D - Tabular Format)

# %%
import pandas as pd

# %%
emp = pd.DataFrame(data)

# %%
emp
# Out:
#    empid empname  empsal
# 0    101    Raju   24565
# 1    102   Raman   78656
# 2    103    Siya   36654
# 3    104  Simran   87686
# 4    105  Yogesh   13324
# 5    106    Ravi   67545
# 6    107  Mahesh   15263
# 7    108   Vikas   21355

# %%
emp.empid
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# Name: empid, dtype: int64

# %%
emp.empname
# Out:
# 0      Raju
# 1     Raman
# 2      Siya
# 3    Simran
# 4    Yogesh
# 5      Ravi
# 6    Mahesh
# 7     Vikas
# Name: empname, dtype: object

# %%
emp.head()
# Out:
#    empid empname  empsal
# 0    101    Raju   24565
# 1    102   Raman   78656
# 2    103    Siya   36654
# 3    104  Simran   87686
# 4    105  Yogesh   13324

# %%
emp.head(2)
# Out:
#    empid empname  empsal
# 0    101    Raju   24565
# 1    102   Raman   78656

# %%
emp.tail()
# Out:
#    empid empname  empsal
# 3    104  Simran   87686
# 4    105  Yogesh   13324
# 5    106    Ravi   67545
# 6    107  Mahesh   15263
# 7    108   Vikas   21355

# %%
emp.tail(2)
# Out:
#    empid empname  empsal
# 6    107  Mahesh   15263
# 7    108   Vikas   21355

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   empid    8 non-null      int64
#  1   empname  8 non-null      object
#  2   empsal   8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 324.0+ bytes

# %%
emp.empsal
# Out:
# 0    24565
# 1    78656
# 2    36654
# 3    87686
# 4    13324
# 5    67545
# 6    15263
# 7    21355
# Name: empsal, dtype: int64

# %%
emp.empsal.sum()
# Out:
# np.int64(345048)

# %%
emp.empsal.mean()
# Out:
# np.float64(43131.0)

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
data = {
    'empid':[101,102,103,104,105,106,107,108],
    'empname':['Raju','Raman',np.nan,'Simran','Yogesh','Ravi','Mahesh','Vikas'],
    'empsal':[24565,78656,36654,87686,13324,np.nan,15263,np.nan]
}

# %%
emp = pd.DataFrame(data)

# %%
emp
# Out:
#    empid empname   empsal
# 0    101    Raju  24565.0
# 1    102   Raman  78656.0
# 2    103     NaN  36654.0
# 3    104  Simran  87686.0
# 4    105  Yogesh  13324.0
# 5    106    Ravi      NaN
# 6    107  Mahesh  15263.0
# 7    108   Vikas      NaN

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   empid    8 non-null      int64
#  1   empname  7 non-null      object
#  2   empsal   6 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 324.0+ bytes

# %%
emp.empsal
# Out:
# 0    24565.0
# 1    78656.0
# 2    36654.0
# 3    87686.0
# 4    13324.0
# 5        NaN
# 6    15263.0
# 7        NaN
# Name: empsal, dtype: float64

# %%
emp.empsal.sum()
# Out:
# np.float64(256148.0)

# %%
emp.empsal.mean()
# Out:
# np.float64(42691.333333333336)

# %%
# Check missing value in DataFrame

# %%
emp.isnull()
# Out:
#    empid  empname  empsal
# 0  False    False   False
# 1  False    False   False
# 2  False     True   False
# 3  False    False   False
# 4  False    False   False
# 5  False    False    True
# 6  False    False   False
# 7  False    False    True

# %%
emp.isnull().sum()
# Out:
# empid      0
# empname    1
# empsal     2
# dtype: int64

# %%
# Fill Missing Value
emp.fillna(value = 0)
# Out:
#    empid empname   empsal
# 0    101    Raju  24565.0
# 1    102   Raman  78656.0
# 2    103       0  36654.0
# 3    104  Simran  87686.0
# 4    105  Yogesh  13324.0
# 5    106    Ravi      0.0
# 6    107  Mahesh  15263.0
# 7    108   Vikas      0.0

# %%
emp.fillna('Missing')
# Out:
#    empid  empname   empsal
# 0    101     Raju  24565.0
# 1    102    Raman  78656.0
# 2    103  Missing  36654.0
# 3    104   Simran  87686.0
# 4    105   Yogesh  13324.0
# 5    106     Ravi  Missing
# 6    107   Mahesh  15263.0
# 7    108    Vikas  Missing

# %%
newemp = emp.copy()

# %%
newemp.empsal = newemp.empsal.fillna(value = 5000)

# %%
newemp
# Out:
#    empid empname   empsal
# 0    101    Raju  24565.0
# 1    102   Raman  78656.0
# 2    103     NaN  36654.0
# 3    104  Simran  87686.0
# 4    105  Yogesh  13324.0
# 5    106    Ravi   5000.0
# 6    107  Mahesh  15263.0
# 7    108   Vikas   5000.0

# %%
newemp = emp.copy()

# %%
newemp.empsal.mean()
# Out:
# np.float64(42691.333333333336)

# %%
newemp
# Out:
#    empid empname   empsal
# 0    101    Raju  24565.0
# 1    102   Raman  78656.0
# 2    103     NaN  36654.0
# 3    104  Simran  87686.0
# 4    105  Yogesh  13324.0
# 5    106    Ravi      NaN
# 6    107  Mahesh  15263.0
# 7    108   Vikas      NaN

# %%
newemp.empsal = newemp.empsal.fillna( value=42691 )

# %%
newemp
# Out:
#    empid empname   empsal
# 0    101    Raju  24565.0
# 1    102   Raman  78656.0
# 2    103     NaN  36654.0
# 3    104  Simran  87686.0
# 4    105  Yogesh  13324.0
# 5    106    Ravi  42691.0
# 6    107  Mahesh  15263.0
# 7    108   Vikas  42691.0

# %%
newemp.empname = newemp.empname.fillna('Not Found')

# %%
newemp
# Out:
#    empid    empname   empsal
# 0    101       Raju  24565.0
# 1    102      Raman  78656.0
# 2    103  Not Found  36654.0
# 3    104     Simran  87686.0
# 4    105     Yogesh  13324.0
# 5    106       Ravi  42691.0
# 6    107     Mahesh  15263.0
# 7    108      Vikas  42691.0
